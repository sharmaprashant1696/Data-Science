# %% [markdown]
#  ## Titanic Survival Project

# %% [markdown]
# ## Problem Statement:
# The Titanic Problem is based on the sinking of the ‘Unsinkable’ ship Titanic in early 1912. It gives you information about multiple people like their ages, sexes, sibling counts, embarkment points, and whether or not they survived the disaster. Based on these features, you have to predict if an arbitrary passenger on Titanic would survive the sinking or not.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df=pd.read_csv('Data/titanic_train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# #### Observation :
# - **This Titanic Dataset contains 891 rows & 12 columns.**
# - **Here our objective is to predict survival using classification algorithim for that Here our target variable is 'Survived'.**
# - **We have 5 features with object datatypes & rest are with numerical features.**

# %% [markdown]
# ### Data Integrity Check

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# - **Missing Value check**

# %%
missing_values = df.isnull().sum().sort_values(ascending = False)
percentage_missing_values =(missing_values/len(df))*100
print(pd.concat([missing_values, percentage_missing_values], axis =1, keys =['Missing Values', '% Missing data']))
# Out:
#              Missing Values  % Missing data
# Cabin                   687       77.104377
# Age                     177       19.865320
# Embarked                  2        0.224467
# PassengerId               0        0.000000
# Name                      0        0.000000
# Pclass                    0        0.000000
# Survived                  0        0.000000
# Sex                       0        0.000000
# Parch                     0        0.000000
# SibSp                     0        0.000000
# Fare                      0        0.000000
# Ticket                    0        0.000000

# %% [markdown]
# ### Observation :
# - **Column 'Age', 'Embarked', and 'Cabin' have null values.**
# - **19.86% of 'Age' data is null value,0.22% of 'Embarked' is null value, while 77.10% 'Cabin' data is null value.**
# - **Dropping 'Cabin' since 77.10% of its values is missing and therefore it cannot contribute to building a good model for predicting the target variable values.**

# %%
df.drop(columns=['Cabin'],inplace = True)

# %% [markdown]
# ## How Many Survived?

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
plt.figure(figsize=(14,7))
sns.set_palette('viridis')
plt.subplot(1,2,1)
df['Survived'].value_counts().plot.pie(explode=[0,0.1],textprops ={ 'fontsize':13,'fontweight' :'bold'},
                                       autopct='%2.1f%%',shadow=True)
plt.title('Survival Distribution',fontsize=18,fontweight ='bold')

plt.subplot(1,2,2)
sns.countplot(x='Survived',data=df)
plt.title('Survival Count',fontsize=18,fontweight ='bold')
plt.xlabel("Survival Category",fontsize=18,fontweight ='bold')
plt.ylabel("Survival Count", fontsize= 18, fontweight='bold')
plt.xticks(fontsize=18,fontweight ='bold',rotation=45)
plt.show()

# %% [markdown]
# #### Observation :-
# > ***It is evident that not many passengers survived the accident.***
# ***
# ***Out of 891 passengers in vessel, only around 342 survived i.e only 38.4% of the passenger survived the crash.***

# %% [markdown]
# ### Let Investiage Gender-wise Survival Rate of Passengers

# %%
df.groupby(['Sex','Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
plt.figure(figsize=(18, 8))

plt.subplot(1, 2, 1)
df.groupby('Sex')['Survived'].mean().plot.bar(color=['skyblue', 'salmon'])
plt.xticks(fontsize=18, fontweight='bold', rotation=0)
plt.title('Gender Wise Mean Survival Rate', fontsize=20, fontweight='bold')
plt.xlabel("Gender", fontsize=18, fontweight='bold')
plt.ylabel("Mean Survival Rate", fontsize=18, fontweight='bold')


plt.subplot(1, 2, 2)

sns.countplot(data=df, x='Sex', hue='Survived') 
plt.title('Gender-wise Survival Rate of Passengers', fontsize=20, fontweight='bold')
plt.xticks(fontsize=18, fontweight='bold')
plt.xlabel("Gender", fontsize=18, fontweight='bold')
plt.ylabel("Survival Count", fontsize=18, fontweight='bold')

plt.tight_layout()
plt.show()

# %% [markdown]
# > **This looks interesting.**
# ***
# ***The number of men on the ship is lot more than the number of women. Still the number of women saved is almost twice the number of males saved.***
# ***The survival rates for a Woman on ship is around 75% while that for men in around 18-19%.***

# %% [markdown]
# ### Exploration of Passengers Class Vs Survival

# %%
pd.crosstab(df.Pclass,df.Survived,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_4939d_row0_col0, #T_4939d_row1_col1, #T_4939d_row1_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_4939d_row0_col1 {
#   background-color: #cee666;
#   color: #000000;
# }
# #T_4939d_row0_col2 {
#   background-color: #f4fa66;
#   color: #000000;
# }
# #T_4939d_row1_col0 {
#   background-color: #f6fa66;
#   color: #000000;
# }
# #T_4939d_row2_col0 {
#   background-color: #60b066;
#   color: #f1f1f1;
# }
# #T_4939d_row2_col1 {
#   background-color: #dfef66;
#   color: #000000;
# }
# #T_4939d_row2_col2 {
#   background-color: #90c866;
#   color: #000000;
# }
# #T_4939d_row3_col0, #T_4939d_row3_col1, #T_4939d_row3_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4939d">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th id="T_4939d_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_4939d_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_4939d_level0_col2" class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Pclass</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4939d_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_4939d_row0_col0" class="data row0 col0" >80</td>
#       <td id="T_4939d_row0_col1" class="data row0 col1" >136</td>
#       <td id="T_4939d_row0_col2" class="data row0 col2" >216</td>
#     </tr>
#     <tr>
#       <th id="T_4939d_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_4939d_row1_col0" class="data row1 col0" >97</td>
#       <td id="T_4939d_row1_col1" class="data row1 col1" >87</td>
#       <td id="T_4939d_row1_col2" class="data row1 col2" >184</td>
#     </tr>
#     <tr>
#       <th id="T_4939d_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_4939d_row2_col0" class="data row2 col0" >372</td>
#       <td id="T_4939d_row2_col1" class="data row2 col1" >119</td>
#       <td id="T_4939d_row2_col2" class="data row2 col2" >491</td>
#     </tr>
#     <tr>
#       <th id="T_4939d_level0_row3" class="row_heading level0 row3" >All</th>
#       <td id="T_4939d_row3_col0" class="data row3 col0" >549</td>
#       <td id="T_4939d_row3_col1" class="data row3 col1" >342</td>
#       <td id="T_4939d_row3_col2" class="data row3 col2" >891</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.figure(figsize=(18, 8))

plt.subplot(1, 2, 1)

df['Pclass'].value_counts().plot.bar(color=['#5DADE2','#58D68D','#F5B041'])

plt.title('Number of Passengers By Pclass', fontsize=20, fontweight='bold')
plt.ylabel('Passengers Count', fontsize=18, fontweight='bold')
plt.xlabel('Passengers Class', fontsize=18, fontweight='bold')
plt.xticks(fontsize=16, fontweight='bold', rotation=0)


plt.subplot(1, 2, 2)

sns.countplot(data=df, x='Pclass', hue='Survived', palette='Set2')

plt.title('Pclass: Survived Vs Dead', fontsize=20, fontweight='bold')
plt.ylabel('Passengers Count', fontsize=18, fontweight='bold')
plt.xlabel('Passengers Class', fontsize=18, fontweight='bold')
plt.xticks(fontsize=16, fontweight='bold')
plt.legend(title="Survived", fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Observation : -
# > ***We can clearly, see that Passengers of <u>Pclass 1 were given a very high priority while rescue</u>. Even though the the number of passengers in Pclass 3 were a lot higher, <u>still the number of survival from Pclass 3 is very low</u>, somewhere around 25%.***
# - **For Pclass 1 % Survived is around 63% while for pclass2 is around 48%. <u>In Conclusion money and status matters.</u> Such a materialistic world.**
# ***
# ### **Lets Dive in little bit more and check for other interesting observations. Lets check survival rate with Sex and Pclass Together.**

# %%
pd.crosstab([df.Sex,df.Survived],df.Pclass, margins= True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_38013_row0_col0, #T_38013_row0_col1, #T_38013_row0_col3, #T_38013_row3_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_38013_row0_col2, #T_38013_row1_col2 {
#   background-color: #f1f866;
#   color: #000000;
# }
# #T_38013_row1_col0 {
#   background-color: #96cb66;
#   color: #000000;
# }
# #T_38013_row1_col1 {
#   background-color: #a3d166;
#   color: #000000;
# }
# #T_38013_row1_col3 {
#   background-color: #cfe766;
#   color: #000000;
# }
# #T_38013_row2_col0 {
#   background-color: #a7d366;
#   color: #000000;
# }
# #T_38013_row2_col1, #T_38013_row2_col3 {
#   background-color: #85c266;
#   color: #000000;
# }
# #T_38013_row2_col2 {
#   background-color: #6eb666;
#   color: #f1f1f1;
# }
# #T_38013_row3_col0 {
#   background-color: #cde666;
#   color: #000000;
# }
# #T_38013_row3_col1 {
#   background-color: #f0f866;
#   color: #000000;
# }
# #T_38013_row3_col3 {
#   background-color: #f7fb66;
#   color: #000000;
# }
# #T_38013_row4_col0, #T_38013_row4_col1, #T_38013_row4_col2, #T_38013_row4_col3 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_38013">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Pclass</th>
#       <th id="T_38013_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_38013_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_38013_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_38013_level0_col3" class="col_heading level0 col3" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="index_name level1" >Survived</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_38013_level0_row0" class="row_heading level0 row0" rowspan="2">female</th>
#       <th id="T_38013_level1_row0" class="row_heading level1 row0" >0</th>
#       <td id="T_38013_row0_col0" class="data row0 col0" >3</td>
#       <td id="T_38013_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_38013_row0_col2" class="data row0 col2" >72</td>
#       <td id="T_38013_row0_col3" class="data row0 col3" >81</td>
#     </tr>
#     <tr>
#       <th id="T_38013_level1_row1" class="row_heading level1 row1" >1</th>
#       <td id="T_38013_row1_col0" class="data row1 col0" >91</td>
#       <td id="T_38013_row1_col1" class="data row1 col1" >70</td>
#       <td id="T_38013_row1_col2" class="data row1 col2" >72</td>
#       <td id="T_38013_row1_col3" class="data row1 col3" >233</td>
#     </tr>
#     <tr>
#       <th id="T_38013_level0_row2" class="row_heading level0 row2" rowspan="2">male</th>
#       <th id="T_38013_level1_row2" class="row_heading level1 row2" >0</th>
#       <td id="T_38013_row2_col0" class="data row2 col0" >77</td>
#       <td id="T_38013_row2_col1" class="data row2 col1" >91</td>
#       <td id="T_38013_row2_col2" class="data row2 col2" >300</td>
#       <td id="T_38013_row2_col3" class="data row2 col3" >468</td>
#     </tr>
#     <tr>
#       <th id="T_38013_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_38013_row3_col0" class="data row3 col0" >45</td>
#       <td id="T_38013_row3_col1" class="data row3 col1" >17</td>
#       <td id="T_38013_row3_col2" class="data row3 col2" >47</td>
#       <td id="T_38013_row3_col3" class="data row3 col3" >109</td>
#     </tr>
#     <tr>
#       <th id="T_38013_level0_row4" class="row_heading level0 row4" >All</th>
#       <th id="T_38013_level1_row4" class="row_heading level1 row4" ></th>
#       <td id="T_38013_row4_col0" class="data row4 col0" >216</td>
#       <td id="T_38013_row4_col1" class="data row4 col1" >184</td>
#       <td id="T_38013_row4_col2" class="data row4 col2" >491</td>
#       <td id="T_38013_row4_col3" class="data row4 col3" >891</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.figure(figsize=(18, 8))
sns.pointplot(data=df,x='Pclass', y='Survived',hue='Sex',palette='Set2')

plt.title('Pclass vs Survival Rate by Sex', fontsize=20, fontweight='bold')
plt.xlabel('Passenger Class', fontsize=18, fontweight='bold')
plt.ylabel('Survival Rate', fontsize=18, fontweight='bold')
plt.xticks(fontsize=16, fontweight='bold')
plt.legend(title="Sex", fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Observation :-
# - **Looking at the CrossTab and the Factorplot, we can easily infer that <u>survival for Women from Pclass 1 is about 95-96%, as only 3 out of 94 Women from Pclass1 died.</u>**
# - **It is evident (from CrossTab and the Factorplot) that irrespective of pclass, women were given first priority while rescue. <u>Even Men from Pclass1 have a very low survival rate.</u>**

# %% [markdown]
# ## Age

# %%
print('Oldest Passenger was of:',df['Age'].max(),'Years')
print('Youngest Passenger was of:',df['Age'].min(),'Years')
print('Average Age on th ship :',df['Age'].mean(),'Years')
# Out:
# Oldest Passenger was of: 80.0 Years
# Youngest Passenger was of: 0.42 Years
# Average Age on th ship : 29.69911764705882 Years

# %%
plt.figure(figsize=(18, 8))

plt.subplot(1, 2, 1)

sns.violinplot(data=df, x='Pclass', y='Age', hue='Survived', split=True, palette='Set2')

plt.title('Pclass Wise Distribution of Age Vs Survived', fontsize=20, fontweight='bold')
plt.xlabel('Passengers Class', fontsize=18, fontweight='bold')
plt.ylabel('Passengers Age', fontsize=18, fontweight='bold')
plt.yticks(range(0, 110, 10))
plt.xticks(fontsize=16, fontweight='bold')


plt.subplot(1, 2, 2)

sns.violinplot(data=df, x='Sex', y='Age', hue='Survived', split=True, palette='Set2')

plt.title('Gender-Wise Age Vs Survived', fontsize=20, fontweight='bold')
plt.xlabel('Gender', fontsize=18, fontweight='bold')
plt.ylabel('Passengers Age', fontsize=18, fontweight='bold')
plt.yticks(range(0, 110, 10))
plt.xticks(fontsize=16, fontweight='bold')

plt.tight_layout()
plt.show()

# %% [markdown]
# - #### Observation :-
#     - **The number of children increases with Pclass and the survival ratee for passenengers below age 10 looks to be good irrespective of the Pclass.**
#     - **Survival chances for Passenegers aged 20-50 from Pclass 1 is high and even better for women.**
#     - **For males, the survival chances decreases with increase in age.**

# %% [markdown]
# ### Handling Missing Values in feature AGE

# %% [markdown]
# > **As we had seen eariler, the Age feature has 177 null values. to replace thses NaN values, we can assign them the mean age of the dataset.**
# ***
# **We cannot simply Assign Mean Age for suppose of 29 year to 4 year old kid. So We must find another way to imputate mean age values.**
#
# ***Looking Upon the name Name Feature, we can see that <u>the names have as salutation like Mr or Mrs. Thus we can assign the mean values of Mr, Mrs etc. to the respective groups</u>.***

# %%
df['Initial']=0
for i in df:
    df['Initial']=df.Name.str.extract("([A-Za-z]+)\.") # Extract the Salutations with Regex

# %%
pd.crosstab(df.Initial,df.Sex).T.style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_f3cdd_row0_col0, #T_f3cdd_row0_col1, #T_f3cdd_row0_col3, #T_f3cdd_row0_col4, #T_f3cdd_row0_col5, #T_f3cdd_row0_col7, #T_f3cdd_row0_col8, #T_f3cdd_row0_col12, #T_f3cdd_row0_col15, #T_f3cdd_row0_col16, #T_f3cdd_row1_col2, #T_f3cdd_row1_col6, #T_f3cdd_row1_col9, #T_f3cdd_row1_col10, #T_f3cdd_row1_col11, #T_f3cdd_row1_col13, #T_f3cdd_row1_col14 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_f3cdd_row0_col2, #T_f3cdd_row0_col6, #T_f3cdd_row0_col9, #T_f3cdd_row0_col10, #T_f3cdd_row0_col11, #T_f3cdd_row0_col13, #T_f3cdd_row0_col14, #T_f3cdd_row1_col0, #T_f3cdd_row1_col1, #T_f3cdd_row1_col3, #T_f3cdd_row1_col4, #T_f3cdd_row1_col5, #T_f3cdd_row1_col7, #T_f3cdd_row1_col8, #T_f3cdd_row1_col12, #T_f3cdd_row1_col15, #T_f3cdd_row1_col16 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f3cdd">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Initial</th>
#       <th id="T_f3cdd_level0_col0" class="col_heading level0 col0" >Capt</th>
#       <th id="T_f3cdd_level0_col1" class="col_heading level0 col1" >Col</th>
#       <th id="T_f3cdd_level0_col2" class="col_heading level0 col2" >Countess</th>
#       <th id="T_f3cdd_level0_col3" class="col_heading level0 col3" >Don</th>
#       <th id="T_f3cdd_level0_col4" class="col_heading level0 col4" >Dr</th>
#       <th id="T_f3cdd_level0_col5" class="col_heading level0 col5" >Jonkheer</th>
#       <th id="T_f3cdd_level0_col6" class="col_heading level0 col6" >Lady</th>
#       <th id="T_f3cdd_level0_col7" class="col_heading level0 col7" >Major</th>
#       <th id="T_f3cdd_level0_col8" class="col_heading level0 col8" >Master</th>
#       <th id="T_f3cdd_level0_col9" class="col_heading level0 col9" >Miss</th>
#       <th id="T_f3cdd_level0_col10" class="col_heading level0 col10" >Mlle</th>
#       <th id="T_f3cdd_level0_col11" class="col_heading level0 col11" >Mme</th>
#       <th id="T_f3cdd_level0_col12" class="col_heading level0 col12" >Mr</th>
#       <th id="T_f3cdd_level0_col13" class="col_heading level0 col13" >Mrs</th>
#       <th id="T_f3cdd_level0_col14" class="col_heading level0 col14" >Ms</th>
#       <th id="T_f3cdd_level0_col15" class="col_heading level0 col15" >Rev</th>
#       <th id="T_f3cdd_level0_col16" class="col_heading level0 col16" >Sir</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f3cdd_level0_row0" class="row_heading level0 row0" >female</th>
#       <td id="T_f3cdd_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_f3cdd_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_f3cdd_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_f3cdd_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_f3cdd_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_f3cdd_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_f3cdd_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_f3cdd_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_f3cdd_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_f3cdd_row0_col9" class="data row0 col9" >182</td>
#       <td id="T_f3cdd_row0_col10" class="data row0 col10" >2</td>
#       <td id="T_f3cdd_row0_col11" class="data row0 col11" >1</td>
#       <td id="T_f3cdd_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_f3cdd_row0_col13" class="data row0 col13" >125</td>
#       <td id="T_f3cdd_row0_col14" class="data row0 col14" >1</td>
#       <td id="T_f3cdd_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_f3cdd_row0_col16" class="data row0 col16" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f3cdd_level0_row1" class="row_heading level0 row1" >male</th>
#       <td id="T_f3cdd_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_f3cdd_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_f3cdd_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_f3cdd_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_f3cdd_row1_col4" class="data row1 col4" >6</td>
#       <td id="T_f3cdd_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_f3cdd_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_f3cdd_row1_col7" class="data row1 col7" >2</td>
#       <td id="T_f3cdd_row1_col8" class="data row1 col8" >40</td>
#       <td id="T_f3cdd_row1_col9" class="data row1 col9" >0</td>
#       <td id="T_f3cdd_row1_col10" class="data row1 col10" >0</td>
#       <td id="T_f3cdd_row1_col11" class="data row1 col11" >0</td>
#       <td id="T_f3cdd_row1_col12" class="data row1 col12" >517</td>
#       <td id="T_f3cdd_row1_col13" class="data row1 col13" >0</td>
#       <td id="T_f3cdd_row1_col14" class="data row1 col14" >0</td>
#       <td id="T_f3cdd_row1_col15" class="data row1 col15" >6</td>
#       <td id="T_f3cdd_row1_col16" class="data row1 col16" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
df['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don'],
                      ['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr'],inplace=True)

# %%
df.groupby('Initial')['Age'].mean()
# Out:
# Initial
# Master     4.574167
# Miss      21.860000
# Mr        32.739609
# Mrs       35.981818
# Other     45.888889
# Name: Age, dtype: float64

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked Initial
# 0      0         A/5 21171   7.2500        S      Mr
# 1      0          PC 17599  71.2833        C     Mrs
# 2      0  STON/O2. 3101282   7.9250        S    Miss
# 3      0            113803  53.1000        S     Mrs
# 4      0            373450   8.0500        S      Mr

# %% [markdown]
# ### Filling NaN Ages

# %%
df.loc[(df.Age.isnull()) & (df.Initial == 'Mr'), 'Age'] = 32.73
df.loc[(df.Age.isnull()) & (df.Initial == 'Mrs'), 'Age'] = 35.98
df.loc[(df.Age.isnull()) & (df.Initial == 'Master'), 'Age'] = 4.57
df.loc[(df.Age.isnull()) & (df.Initial == 'Miss'), 'Age'] = 21.86
df.loc[(df.Age.isnull()) & (df.Initial == 'Other'), 'Age'] = 45.889

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# Initial        0
# dtype: int64

# %%
plt.figure(figsize=(18, 8))

plt.subplot(1, 2, 1)

df[df['Survived'] == 0]['Age'].plot.hist(bins=20,edgecolor='black',color='skyblue')

plt.title('Survived = 0', fontsize=20, fontweight='bold')
plt.xlabel('Passengers Age', fontsize=18, fontweight='bold')
plt.ylabel('Passengers Count', fontsize=18, fontweight='bold')
plt.xticks(range(0, 85, 5), fontsize=16, fontweight='bold')

plt.subplot(1, 2, 2)

df[df['Survived'] == 1]['Age'].plot.hist(bins=20,edgecolor='black',color='salmon')

plt.title('Survived = 1', fontsize=20, fontweight='bold')
plt.xlabel('Passengers Age', fontsize=18, fontweight='bold')
plt.ylabel('Passengers Count', fontsize=18, fontweight='bold')
plt.xticks(range(0, 85, 5), fontsize=16, fontweight='bold')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Observation :-
# - **The Toddlers(age<5) were saved in large numbers. Possibliy, <u>Women and Child first policy employs while rescue operation employed.</u>**
# - **The oldest Passenger was saved (80 years).**
# - **Maximum number of deaths were in <u>age group of 30-40.</u>**

# %%
g = sns.catplot(data=df,x='Pclass',y='Survived',col='Initial',kind='point',height=5,aspect=1)

g.set_titles("Initial: {col_name}")
g.set_axis_labels("Passenger Class", "Survival Rate")

plt.tight_layout()
plt.show()

# %% [markdown]
# > <b> The women and child first policy thus holds true irrespective of the class.</b>

# %% [markdown]
# ### Analysis Embarked vs Survival

# %%
pd.crosstab([df.Embarked,df.Pclass],[df.Sex,df.Survived],margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_50f6e_row0_col0, #T_50f6e_row1_col2 {
#   background-color: #fcfe66;
#   color: #000000;
# }
# #T_50f6e_row0_col1 {
#   background-color: #d2e866;
#   color: #000000;
# }
# #T_50f6e_row0_col2 {
#   background-color: #f2f866;
#   color: #000000;
# }
# #T_50f6e_row0_col3 {
#   background-color: #d8ec66;
#   color: #000000;
# }
# #T_50f6e_row0_col4, #T_50f6e_row2_col3 {
#   background-color: #e8f466;
#   color: #000000;
# }
# #T_50f6e_row1_col0, #T_50f6e_row3_col0, #T_50f6e_row3_col1, #T_50f6e_row3_col2, #T_50f6e_row3_col3, #T_50f6e_row3_col4, #T_50f6e_row4_col0, #T_50f6e_row4_col2, #T_50f6e_row4_col3, #T_50f6e_row4_col4 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_50f6e_row1_col1, #T_50f6e_row6_col0 {
#   background-color: #f9fc66;
#   color: #000000;
# }
# #T_50f6e_row1_col3, #T_50f6e_row1_col4 {
#   background-color: #fbfd66;
#   color: #000000;
# }
# #T_50f6e_row2_col0, #T_50f6e_row5_col1 {
#   background-color: #e6f266;
#   color: #000000;
# }
# #T_50f6e_row2_col1 {
#   background-color: #f0f866;
#   color: #000000;
# }
# #T_50f6e_row2_col2 {
#   background-color: #eef666;
#   color: #000000;
# }
# #T_50f6e_row2_col4, #T_50f6e_row7_col0 {
#   background-color: #edf666;
#   color: #000000;
# }
# #T_50f6e_row4_col1 {
#   background-color: #fefe66;
#   color: #000000;
# }
# #T_50f6e_row5_col0 {
#   background-color: #e3f166;
#   color: #000000;
# }
# #T_50f6e_row5_col2 {
#   background-color: #ecf666;
#   color: #000000;
# }
# #T_50f6e_row5_col3 {
#   background-color: #f8fc66;
#   color: #000000;
# }
# #T_50f6e_row5_col4 {
#   background-color: #ebf566;
#   color: #000000;
# }
# #T_50f6e_row6_col1 {
#   background-color: #cde666;
#   color: #000000;
# }
# #T_50f6e_row6_col2 {
#   background-color: #e4f266;
#   color: #000000;
# }
# #T_50f6e_row6_col3 {
#   background-color: #bede66;
#   color: #000000;
# }
# #T_50f6e_row6_col4 {
#   background-color: #dbed66;
#   color: #000000;
# }
# #T_50f6e_row7_col1 {
#   background-color: #bdde66;
#   color: #000000;
# }
# #T_50f6e_row7_col2 {
#   background-color: #d3e966;
#   color: #000000;
# }
# #T_50f6e_row7_col3, #T_50f6e_row8_col1 {
#   background-color: #dcee66;
#   color: #000000;
# }
# #T_50f6e_row7_col4 {
#   background-color: #d1e866;
#   color: #000000;
# }
# #T_50f6e_row8_col0 {
#   background-color: #52a866;
#   color: #f1f1f1;
# }
# #T_50f6e_row8_col2 {
#   background-color: #81c066;
#   color: #000000;
# }
# #T_50f6e_row8_col3 {
#   background-color: #b0d866;
#   color: #000000;
# }
# #T_50f6e_row8_col4 {
#   background-color: #9acc66;
#   color: #000000;
# }
# #T_50f6e_row9_col0, #T_50f6e_row9_col1, #T_50f6e_row9_col2, #T_50f6e_row9_col3, #T_50f6e_row9_col4 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_50f6e">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Sex</th>
#       <th id="T_50f6e_level0_col0" class="col_heading level0 col0" colspan="2">female</th>
#       <th id="T_50f6e_level0_col2" class="col_heading level0 col2" colspan="2">male</th>
#       <th id="T_50f6e_level0_col4" class="col_heading level0 col4" >All</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >Survived</th>
#       <th id="T_50f6e_level1_col0" class="col_heading level1 col0" >0</th>
#       <th id="T_50f6e_level1_col1" class="col_heading level1 col1" >1</th>
#       <th id="T_50f6e_level1_col2" class="col_heading level1 col2" >0</th>
#       <th id="T_50f6e_level1_col3" class="col_heading level1 col3" >1</th>
#       <th id="T_50f6e_level1_col4" class="col_heading level1 col4" ></th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Embarked</th>
#       <th class="index_name level1" >Pclass</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_50f6e_level0_row0" class="row_heading level0 row0" rowspan="3">C</th>
#       <th id="T_50f6e_level1_row0" class="row_heading level1 row0" >1</th>
#       <td id="T_50f6e_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_50f6e_row0_col1" class="data row0 col1" >42</td>
#       <td id="T_50f6e_row0_col2" class="data row0 col2" >25</td>
#       <td id="T_50f6e_row0_col3" class="data row0 col3" >17</td>
#       <td id="T_50f6e_row0_col4" class="data row0 col4" >85</td>
#     </tr>
#     <tr>
#       <th id="T_50f6e_level1_row1" class="row_heading level1 row1" >2</th>
#       <td id="T_50f6e_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_50f6e_row1_col1" class="data row1 col1" >7</td>
#       <td id="T_50f6e_row1_col2" class="data row1 col2" >8</td>
#       <td id="T_50f6e_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_50f6e_row1_col4" class="data row1 col4" >17</td>
#     </tr>
#     <tr>
#       <th id="T_50f6e_level1_row2" class="row_heading level1 row2" >3</th>
#       <td id="T_50f6e_row2_col0" class="data row2 col0" >8</td>
#       <td id="T_50f6e_row2_col1" class="data row2 col1" >15</td>
#       <td id="T_50f6e_row2_col2" class="data row2 col2" >33</td>
#       <td id="T_50f6e_row2_col3" class="data row2 col3" >10</td>
#       <td id="T_50f6e_row2_col4" class="data row2 col4" >66</td>
#     </tr>
#     <tr>
#       <th id="T_50f6e_level0_row3" class="row_heading level0 row3" rowspan="3">Q</th>
#       <th id="T_50f6e_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_50f6e_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_50f6e_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_50f6e_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_50f6e_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_50f6e_row3_col4" class="data row3 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_50f6e_level1_row4" class="row_heading level1 row4" >2</th>
#       <td id="T_50f6e_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_50f6e_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_50f6e_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_50f6e_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_50f6e_row4_col4" class="data row4 col4" >3</td>
#     </tr>
#     <tr>
#       <th id="T_50f6e_level1_row5" class="row_heading level1 row5" >3</th>
#       <td id="T_50f6e_row5_col0" class="data row5 col0" >9</td>
#       <td id="T_50f6e_row5_col1" class="data row5 col1" >24</td>
#       <td id="T_50f6e_row5_col2" class="data row5 col2" >36</td>
#       <td id="T_50f6e_row5_col3" class="data row5 col3" >3</td>
#       <td id="T_50f6e_row5_col4" class="data row5 col4" >72</td>
#     </tr>
#     <tr>
#       <th id="T_50f6e_level0_row6" class="row_heading level0 row6" rowspan="3">S</th>
#       <th id="T_50f6e_level1_row6" class="row_heading level1 row6" >1</th>
#       <td id="T_50f6e_row6_col0" class="data row6 col0" >2</td>
#       <td id="T_50f6e_row6_col1" class="data row6 col1" >46</td>
#       <td id="T_50f6e_row6_col2" class="data row6 col2" >51</td>
#       <td id="T_50f6e_row6_col3" class="data row6 col3" >28</td>
#       <td id="T_50f6e_row6_col4" class="data row6 col4" >127</td>
#     </tr>
#     <tr>
#       <th id="T_50f6e_level1_row7" class="row_heading level1 row7" >2</th>
#       <td id="T_50f6e_row7_col0" class="data row7 col0" >6</td>
#       <td id="T_50f6e_row7_col1" class="data row7 col1" >61</td>
#       <td id="T_50f6e_row7_col2" class="data row7 col2" >82</td>
#       <td id="T_50f6e_row7_col3" class="data row7 col3" >15</td>
#       <td id="T_50f6e_row7_col4" class="data row7 col4" >164</td>
#     </tr>
#     <tr>
#       <th id="T_50f6e_level1_row8" class="row_heading level1 row8" >3</th>
#       <td id="T_50f6e_row8_col0" class="data row8 col0" >55</td>
#       <td id="T_50f6e_row8_col1" class="data row8 col1" >33</td>
#       <td id="T_50f6e_row8_col2" class="data row8 col2" >231</td>
#       <td id="T_50f6e_row8_col3" class="data row8 col3" >34</td>
#       <td id="T_50f6e_row8_col4" class="data row8 col4" >353</td>
#     </tr>
#     <tr>
#       <th id="T_50f6e_level0_row9" class="row_heading level0 row9" >All</th>
#       <th id="T_50f6e_level1_row9" class="row_heading level1 row9" ></th>
#       <td id="T_50f6e_row9_col0" class="data row9 col0" >81</td>
#       <t

# %% [markdown]
# ### <b> Chances for Survival by Port of Embarkation </b>

# %%
plt.figure(figsize=(6,4))

sns.pointplot(data=df,x='Embarked',y='Survived',color='red')

plt.title('Embarked vs Survived', fontsize=20, fontweight='bold')
plt.xlabel('Embarked', fontsize=18, fontweight='bold')
plt.ylabel('Survived', fontsize=18, fontweight='bold')
plt.xticks(fontsize=16, fontweight='bold')

plt.tight_layout()
plt.show()

# %% [markdown]
# **The chances for survival for port C is highest around 0.55 while it is lowest for S.**

# %%
plt.figure(figsize=(20,18))

plt.subplot(2,2,1)

sns.countplot(data=df, x='Embarked', palette='Set2')

plt.title('No of Passengers Boarded', fontsize=20, fontweight='bold')
plt.xlabel('Embarked', fontsize=18, fontweight='bold')
plt.ylabel('Passengers Count', fontsize=18, fontweight='bold')
plt.xticks(fontsize=16, fontweight='bold')

plt.subplot(2,2,2)

sns.countplot(data=df, x='Embarked', hue='Sex', palette='coolwarm')

plt.title('Male - Female Split for Embarked', fontsize=20, fontweight='bold')
plt.xlabel('Embarked', fontsize=18, fontweight='bold')
plt.ylabel('Passengers Count', fontsize=18, fontweight='bold')
plt.xticks(fontsize=16, fontweight='bold')

plt.subplot(2,2,3)

sns.countplot(data=df, x='Embarked', hue='Survived', palette='Set1')

plt.title('Embarked vs Survived', fontsize=20, fontweight='bold')
plt.xlabel('Embarked', fontsize=18, fontweight='bold')
plt.ylabel('Passengers Count', fontsize=18, fontweight='bold')
plt.xticks(fontsize=16, fontweight='bold')

plt.subplot(2,2,4)

sns.countplot(data=df, x='Embarked', hue='Pclass', palette='viridis')

plt.title('Embarked vs Pclass', fontsize=20, fontweight='bold')
plt.xlabel('Embarked', fontsize=18, fontweight='bold')
plt.ylabel('Passengers Count', fontsize=18, fontweight='bold')
plt.xticks(fontsize=16, fontweight='bold')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Observation :-
#
#    - **Maximum passengers boarded from S. <u>Majority of them being from Pclass 3.</u>**
#    - **The Passengers from C look to be lucky as as good proportion of them survived.** The reason for this may be the rescue of all the Pclass 1 and Pclass 2 Passengers.
#    - **<u>The Embark S looks to the port from where majority of the rich people.</u> Still the chances for survival is low here, that is because many passengers from Pclass 3 around 81% didn't survive.**
#    - Port Q had almost 95% of the passengers were from Pclass 3.

# %%
sns.catplot(x='Pclass', y='Survived', hue='Sex', col='Embarked', data=df, kind='point')

plt.show()

# %% [markdown]
# ### Observation :-
#    - **The survival chances are almost 1 for women for Pclass 1 and Pclass 2 irrespective of the Pclass.**
#    - **Port S looks to be very unlucky for Pclass 3 passengers** as the survival rate for both men and women is very low.
#    - **Port Q looks to be unluckiest for Men, as almost all were from Pclass 3.**

# %% [markdown]
# ### Filling Embarked NaN

# %% [markdown]
# As we saw that maximum passengers boarded from Port S, we replace NaN with S.

# %%
df['Embarked'].fillna('S', inplace=True)

# %%
df.Embarked.isnull().any()
# Out:
# np.False_

# %% [markdown]
# # SibSip vs Survived

# %%
pd.crosstab([df.SibSp],[df.Survived],margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_37573_row0_col0 {
#   background-color: #47a366;
#   color: #f1f1f1;
# }
# #T_37573_row0_col1 {
#   background-color: #62b066;
#   color: #f1f1f1;
# }
# #T_37573_row0_col2 {
#   background-color: #51a866;
#   color: #f1f1f1;
# }
# #T_37573_row1_col0 {
#   background-color: #d4ea66;
#   color: #000000;
# }
# #T_37573_row1_col1 {
#   background-color: #acd666;
#   color: #000000;
# }
# #T_37573_row1_col2 {
#   background-color: #c5e266;
#   color: #000000;
# }
# #T_37573_row2_col0, #T_37573_row4_col0 {
#   background-color: #fbfd66;
#   color: #000000;
# }
# #T_37573_row2_col1 {
#   background-color: #f6fa66;
#   color: #000000;
# }
# #T_37573_row2_col2 {
#   background-color: #f9fc66;
#   color: #000000;
# }
# #T_37573_row3_col0, #T_37573_row3_col2, #T_37573_row4_col2 {
#   background-color: #fcfe66;
#   color: #000000;
# }
# #T_37573_row3_col1, #T_37573_row4_col1 {
#   background-color: #fdfe66;
#   color: #000000;
# }
# #T_37573_row5_col0, #T_37573_row5_col1, #T_37573_row5_col2, #T_37573_row6_col0, #T_37573_row6_col1, #T_37573_row6_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_37573_row7_col0, #T_37573_row7_col1, #T_37573_row7_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_37573">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th id="T_37573_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_37573_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_37573_level0_col2" class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >SibSp</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_37573_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_37573_row0_col0" class="data row0 col0" >398</td>
#       <td id="T_37573_row0_col1" class="data row0 col1" >210</td>
#       <td id="T_37573_row0_col2" class="data row0 col2" >608</td>
#     </tr>
#     <tr>
#       <th id="T_37573_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_37573_row1_col0" class="data row1 col0" >97</td>
#       <td id="T_37573_row1_col1" class="data row1 col1" >112</td>
#       <td id="T_37573_row1_col2" class="data row1 col2" >209</td>
#     </tr>
#     <tr>
#       <th id="T_37573_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_37573_row2_col0" class="data row2 col0" >15</td>
#       <td id="T_37573_row2_col1" class="data row2 col1" >13</td>
#       <td id="T_37573_row2_col2" class="data row2 col2" >28</td>
#     </tr>
#     <tr>
#       <th id="T_37573_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_37573_row3_col0" class="data row3 col0" >12</td>
#       <td id="T_37573_row3_col1" class="data row3 col1" >4</td>
#       <td id="T_37573_row3_col2" class="data row3 col2" >16</td>
#     </tr>
#     <tr>
#       <th id="T_37573_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_37573_row4_col0" class="data row4 col0" >15</td>
#       <td id="T_37573_row4_col1" class="data row4 col1" >3</td>
#       <td id="T_37573_row4_col2" class="data row4 col2" >18</td>
#     </tr>
#     <tr>
#       <th id="T_37573_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_37573_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_37573_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_37573_row5_col2" class="data row5 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_37573_level0_row6" class="row_heading level0 row6" >8</th>
#       <td id="T_37573_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_37573_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_37573_row6_col2" class="data row6 col2" >7</td>
#     </tr>
#     <tr>
#       <th id="T_37573_level0_row7" class="row_heading level0 row7" >All</th>
#       <td id="T_37573_row7_col0" class="data row7 col0" >549</td>
#       <td id="T_37573_row7_col1" class="data row7 col1" >342</td>
#       <td id="T_37573_row7_col2" class="data row7 col2" >891</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.figure(figsize=(18,8))

plt.subplot(1,2,1)

sns.barplot(data=df, x='SibSp', y='Survived', palette='Set2')

plt.title('SibSp Vs Survived', fontsize=20, fontweight='bold')
plt.xlabel('SibSp', fontsize=18, fontweight='bold')
plt.ylabel('Survival Rate', fontsize=18, fontweight='bold')
plt.xticks(fontsize=16, fontweight='bold')

plt.subplot(1,2,2)

sns.pointplot(data=df, x='SibSp', y='Survived', color='orange')

plt.title('SibSp Vs Survived', fontsize=20, fontweight='bold')
plt.xlabel('SibSp', fontsize=18, fontweight='bold')
plt.ylabel('Survival Rate', fontsize=18, fontweight='bold')
plt.xticks(fontsize=16, fontweight='bold')

plt.tight_layout()
plt.show()

# %%
pd.crosstab([df.SibSp],[df.Pclass],margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_9a19c_row0_col0 {
#   background-color: #5dae66;
#   color: #f1f1f1;
# }
# #T_9a19c_row0_col1 {
#   background-color: #59ac66;
#   color: #f1f1f1;
# }
# #T_9a19c_row0_col2 {
#   background-color: #49a466;
#   color: #f1f1f1;
# }
# #T_9a19c_row0_col3 {
#   background-color: #51a866;
#   color: #f1f1f1;
# }
# #T_9a19c_row1_col0 {
#   background-color: #abd566;
#   color: #000000;
# }
# #T_9a19c_row1_col1 {
#   background-color: #b3d966;
#   color: #000000;
# }
# #T_9a19c_row1_col2 {
#   background-color: #d6eb66;
#   color: #000000;
# }
# #T_9a19c_row1_col3 {
#   background-color: #c5e266;
#   color: #000000;
# }
# #T_9a19c_row2_col0, #T_9a19c_row2_col2 {
#   background-color: #fafc66;
#   color: #000000;
# }
# #T_9a19c_row2_col1 {
#   background-color: #f4fa66;
#   color: #000000;
# }
# #T_9a19c_row2_col3, #T_9a19c_row4_col2 {
#   background-color: #f9fc66;
#   color: #000000;
# }
# #T_9a19c_row3_col0, #T_9a19c_row3_col2, #T_9a19c_row3_col3, #T_9a19c_row4_col3 {
#   background-color: #fcfe66;
#   color: #000000;
# }
# #T_9a19c_row3_col1, #T_9a19c_row6_col2 {
#   background-color: #fefe66;
#   color: #000000;
# }
# #T_9a19c_row4_col0, #T_9a19c_row4_col1, #T_9a19c_row5_col0, #T_9a19c_row5_col1, #T_9a19c_row5_col2, #T_9a19c_row5_col3, #T_9a19c_row6_col0, #T_9a19c_row6_col1, #T_9a19c_row6_col3 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_9a19c_row7_col0, #T_9a19c_row7_col1, #T_9a19c_row7_col2, #T_9a19c_row7_col3 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9a19c">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Pclass</th>
#       <th id="T_9a19c_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_9a19c_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_9a19c_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_9a19c_level0_col3" class="col_heading level0 col3" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >SibSp</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9a19c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9a19c_row0_col0" class="data row0 col0" >137</td>
#       <td id="T_9a19c_row0_col1" class="data row0 col1" >120</td>
#       <td id="T_9a19c_row0_col2" class="data row0 col2" >351</td>
#       <td id="T_9a19c_row0_col3" class="data row0 col3" >608</td>
#     </tr>
#     <tr>
#       <th id="T_9a19c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9a19c_row1_col0" class="data row1 col0" >71</td>
#       <td id="T_9a19c_row1_col1" class="data row1 col1" >55</td>
#       <td id="T_9a19c_row1_col2" class="data row1 col2" >83</td>
#       <td id="T_9a19c_row1_col3" class="data row1 col3" >209</td>
#     </tr>
#     <tr>
#       <th id="T_9a19c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9a19c_row2_col0" class="data row2 col0" >5</td>
#       <td id="T_9a19c_row2_col1" class="data row2 col1" >8</td>
#       <td id="T_9a19c_row2_col2" class="data row2 col2" >15</td>
#       <td id="T_9a19c_row2_col3" class="data row2 col3" >28</td>
#     </tr>
#     <tr>
#       <th id="T_9a19c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9a19c_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_9a19c_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_9a19c_row3_col2" class="data row3 col2" >12</td>
#       <td id="T_9a19c_row3_col3" class="data row3 col3" >16</td>
#     </tr>
#     <tr>
#       <th id="T_9a19c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9a19c_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_9a19c_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_9a19c_row4_col2" class="data row4 col2" >18</td>
#       <td id="T_9a19c_row4_col3" class="data row4 col3" >18</td>
#     </tr>
#     <tr>
#       <th id="T_9a19c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9a19c_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_9a19c_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_9a19c_row5_col2" class="data row5 col2" >5</td>
#       <td id="T_9a19c_row5_col3" class="data row5 col3" >5</td>
#     </tr>
#     <tr>
#       <th id="T_9a19c_level0_row6" class="row_heading level0 row6" >8</th>
#       <td id="T_9a19c_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_9a19c_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_9a19c_row6_col2" class="data row6 col2" >7</td>
#       <td id="T_9a19c_row6_col3" class="data row6 col3" >7</td>
#     </tr>
#     <tr>
#       <th id="T_9a19c_level0_row7" class="row_heading level0 row7" >All</th>
#       <td id="T_9a19c_row7_col0" class="data row7 col0" >216</td>
#       <td id="T_9a19c_row7_col1" class="data row7 col1" >184</td>
#       <td id="T_9a19c_row7_col2" class="data row7 col2" >491</td>
#       <td id="T_9a19c_row7_col3" class="data row7 col3" >891</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Observation :-
# - The barplot and factor plot show that if as passenger is alone onboard with no siblings, **Passenger have 34.5% survival rate. The graph roughly decreases if the number of sibilings increase.**
#
#     <u>***Surprisingly the survival for families with 5-8 members is 0% . The reason may be Pclass ?***</u>
#
#
# - <em> **The crosstab shows that person with SibSp>3 were all in Pclass. It is imminent that all the large families in Pclass 3 (>3) died.**</em>

# %% [markdown]
# ## Parch Vs Survial

# %%
pd.crosstab([df.Parch],[df.Pclass],margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_d54aa_row0_col0 {
#   background-color: #3e9e66;
#   color: #f1f1f1;
# }
# #T_d54aa_row0_col1 {
#   background-color: #45a266;
#   color: #f1f1f1;
# }
# #T_d54aa_row0_col2 {
#   background-color: #399c66;
#   color: #f1f1f1;
# }
# #T_d54aa_row0_col3 {
#   background-color: #3d9e66;
#   color: #f1f1f1;
# }
# #T_d54aa_row1_col0 {
#   background-color: #dbed66;
#   color: #000000;
# }
# #T_d54aa_row1_col1 {
#   background-color: #d3e966;
#   color: #000000;
# }
# #T_d54aa_row1_col2 {
#   background-color: #e3f166;
#   color: #000000;
# }
# #T_d54aa_row1_col3 {
#   background-color: #deee66;
#   color: #000000;
# }
# #T_d54aa_row2_col0 {
#   background-color: #e7f366;
#   color: #000000;
# }
# #T_d54aa_row2_col1, #T_d54aa_row2_col3 {
#   background-color: #e9f466;
#   color: #000000;
# }
# #T_d54aa_row2_col2 {
#   background-color: #eaf466;
#   color: #000000;
# }
# #T_d54aa_row3_col0, #T_d54aa_row4_col1, #T_d54aa_row4_col3, #T_d54aa_row5_col0, #T_d54aa_row5_col1, #T_d54aa_row6_col0, #T_d54aa_row6_col1, #T_d54aa_row6_col2, #T_d54aa_row6_col3 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_d54aa_row3_col1, #T_d54aa_row5_col2 {
#   background-color: #fdfe66;
#   color: #000000;
# }
# #T_d54aa_row3_col2, #T_d54aa_row3_col3, #T_d54aa_row4_col0, #T_d54aa_row4_col2, #T_d54aa_row5_col3 {
#   background-color: #fefe66;
#   color: #000000;
# }
# #T_d54aa_row7_col0, #T_d54aa_row7_col1, #T_d54aa_row7_col2, #T_d54aa_row7_col3 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d54aa">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Pclass</th>
#       <th id="T_d54aa_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_d54aa_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_d54aa_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_d54aa_level0_col3" class="col_heading level0 col3" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Parch</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d54aa_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d54aa_row0_col0" class="data row0 col0" >163</td>
#       <td id="T_d54aa_row0_col1" class="data row0 col1" >134</td>
#       <td id="T_d54aa_row0_col2" class="data row0 col2" >381</td>
#       <td id="T_d54aa_row0_col3" class="data row0 col3" >678</td>
#     </tr>
#     <tr>
#       <th id="T_d54aa_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d54aa_row1_col0" class="data row1 col0" >31</td>
#       <td id="T_d54aa_row1_col1" class="data row1 col1" >32</td>
#       <td id="T_d54aa_row1_col2" class="data row1 col2" >55</td>
#       <td id="T_d54aa_row1_col3" class="data row1 col3" >118</td>
#     </tr>
#     <tr>
#       <th id="T_d54aa_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d54aa_row2_col0" class="data row2 col0" >21</td>
#       <td id="T_d54aa_row2_col1" class="data row2 col1" >16</td>
#       <td id="T_d54aa_row2_col2" class="data row2 col2" >43</td>
#       <td id="T_d54aa_row2_col3" class="data row2 col3" >80</td>
#     </tr>
#     <tr>
#       <th id="T_d54aa_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d54aa_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_d54aa_row3_col1" class="data row3 col1" >2</td>
#       <td id="T_d54aa_row3_col2" class="data row3 col2" >3</td>
#       <td id="T_d54aa_row3_col3" class="data row3 col3" >5</td>
#     </tr>
#     <tr>
#       <th id="T_d54aa_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d54aa_row4_col0" class="data row4 col0" >1</td>
#       <td id="T_d54aa_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_d54aa_row4_col2" class="data row4 col2" >3</td>
#       <td id="T_d54aa_row4_col3" class="data row4 col3" >4</td>
#     </tr>
#     <tr>
#       <th id="T_d54aa_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d54aa_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_d54aa_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_d54aa_row5_col2" class="data row5 col2" >5</td>
#       <td id="T_d54aa_row5_col3" class="data row5 col3" >5</td>
#     </tr>
#     <tr>
#       <th id="T_d54aa_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d54aa_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_d54aa_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_d54aa_row6_col2" class="data row6 col2" >1</td>
#       <td id="T_d54aa_row6_col3" class="data row6 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d54aa_level0_row7" class="row_heading level0 row7" >All</th>
#       <td id="T_d54aa_row7_col0" class="data row7 col0" >216</td>
#       <td id="T_d54aa_row7_col1" class="data row7 col1" >184</td>
#       <td id="T_d54aa_row7_col2" class="data row7 col2" >491</td>
#       <td id="T_d54aa_row7_col3" class="data row7 col3" >891</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.figure(figsize=(18,8))

plt.subplot(1,2,1)

sns.barplot(data=df, x='Parch', y='Survived', palette='Set2')

plt.title('Parch Vs Survived', fontsize=20, fontweight='bold')
plt.xlabel('Parch', fontsize=18, fontweight='bold')
plt.ylabel('Survival Rate', fontsize=18, fontweight='bold')
plt.xticks(fontsize=16, fontweight='bold')

plt.subplot(1,2,2)

sns.pointplot(data=df, x='Parch', y='Survived', color='orange')

plt.title('Parch Vs Survived', fontsize=20, fontweight='bold')
plt.xlabel('Parch', fontsize=18, fontweight='bold')
plt.ylabel('Survival Rate', fontsize=18, fontweight='bold')
plt.xticks(fontsize=16, fontweight='bold')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Observation :-
#    - Here too the results are quite similar. ***Passengers with their parents onboard have greater chance of survival.*** it however reduces as the number goes up.
#    - **The chances of survival is good for somebody who has 1-3 parents on the ship.**

# %% [markdown]
# ## Fare Vs Survival

# %%
print('Highest Fare was :',df['Fare'].max())
print('Highest Fare was :',df['Fare'].min())
print('Average Fare was :',df['Fare'].mean())
# Out:
# Highest Fare was : 512.3292
# Highest Fare was : 0.0
# Average Fare was : 32.204207968574636

# %%
plt.figure(figsize=(20,7))

plt.subplot(1,3,1)

sns.histplot(df[df['Pclass']==1]['Fare'], kde=True, color='blue')

plt.title('Fares in Pclass 1', fontsize=20, fontweight='bold')
plt.xlabel('Fares', fontsize=18, fontweight='bold')
plt.ylabel('Density', fontsize=18, fontweight='bold')

plt.subplot(1,3,2)

sns.histplot(df[df['Pclass']==2]['Fare'], kde=True, color='green')

plt.title('Fares in Pclass 2', fontsize=20, fontweight='bold')
plt.xlabel('Fares', fontsize=18, fontweight='bold')
plt.ylabel('Density', fontsize=18, fontweight='bold')

plt.subplot(1,3,3)

sns.histplot(df[df['Pclass']==3]['Fare'], kde=True, color='red')

plt.title('Fares in Pclass 3', fontsize=20, fontweight='bold')
plt.xlabel('Fares', fontsize=18, fontweight='bold')
plt.ylabel('Density', fontsize=18, fontweight='bold')

plt.tight_layout()
plt.show()

# %% [markdown]
# - **There looks to be a large distribution in the fares of Passengers in Pclass1 and this distribution goes on decreasing as the standards reduces. As this is also Continous , we can convert into discrete values by using binning**

# %%
sns.pairplot(data=df, hue='Pclass')

plt.show()

# %% [markdown]
# ###  Outliers Detection and Removal

# %%
# Droping unnecessary column for further investigation
df.drop(["PassengerId", "Name" , "Ticket" ],axis=1,inplace=True)

# %%
# As we have lot of Columns Lets sort Columns by their datatype
df.columns.to_series().groupby(df.dtypes).groups
# Out:
# {int64: ['Survived', 'Pclass', 'SibSp', 'Parch'], float64: ['Age', 'Fare'], object: ['Sex', 'Embarked', 'Initial']}

# %%
Numerical_features= ['Survived', 'Pclass', 'SibSp', 'Parch','Age', 'Fare']
Categorical_features = ['Sex', 'Embarked', 'Initial']

# %%
# Identifying outliers using boxplots
plt.figure(figsize=(12,10), facecolor='white')

plotnumber = 1

for feature in Numerical_features:
    if plotnumber <= 9:
        plt.subplot(3,3,plotnumber)
        
        sns.boxplot(x=df[feature], color='skyblue')
        
        plt.title(f'Outliers in {feature}', fontsize=14, fontweight='bold')
        plt.xlabel(feature, fontsize=12, fontweight='bold')
        
        plotnumber += 1

plt.tight_layout()
plt.show()

# %% [markdown]
# - **We can see that continous features like age & fare contains outliers.**

# %%
# Outlier detection 

def detect_outliers(df,n,features):
    """
    Takes a dataframe df of features and returns a list of the indices
    corresponding to the observations containing more than n outliers according
    to the Tukey method.
    """
    outlier_indices = []
    
    # iterate over features(columns)
    for col in features:
        # 1st quartile (25%)
        Q1 = np.percentile(df[col], 25)
        # 3rd quartile (75%)
        Q3 = np.percentile(df[col],75)
        # Interquartile range (IQR)
        IQR = Q3 - Q1
        
        # outlier step
        outlier_step = 1.5 * IQR
        
        # Determine a list of indices of outliers for feature col
        outlier_list_col = df[(df[col] < Q1 - outlier_step) | (df[col] > Q3 + outlier_step )].index
        
        # append the found outlier indices for col to the list of outlier indices 
        outlier_indices.extend(outlier_list_col)
        
    # select observations containing more than 2 outliers
    outlier_indices = Counter(outlier_indices)        
    multiple_outliers = list( k for k, v in outlier_indices.items() if v > n )
    
    return multiple_outliers

# %%
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked Initial
# 0         0       3    male  22.0      1      0   7.2500        S      Mr
# 1         1       1  female  38.0      1      0  71.2833        C     Mrs
# 2         1       3  female  26.0      0      0   7.9250        S    Miss
# 3         1       1  female  35.0      1      0  53.1000        S     Mrs
# 4         0       3    male  35.0      0      0   8.0500        S      Mr

# %%
# detect outliers from Age, SibSp , Parch and Fare
from collections import Counter
Outliers_to_drop = detect_outliers(df,2,["Age","SibSp","Parch","Fare"])

# %%
# Drop outliers
df = df.drop(Outliers_to_drop, axis = 0).reset_index(drop=True)

# %%
df.shape
# Out:
# (876, 9)

# %%
# Filling missing value of Age 

## Fill Age with the median age of similar rows according to Pclass, Parch and SibSp
# Index of NaN age rows
index_NaN_age = list(df["Age"][df["Age"].isnull()].index)

for i in index_NaN_age :
    age_med = df["Age"].median()
    age_pred = df["Age"][((df['SibSp'] == df.iloc[i]["SibSp"]) & (df['Parch'] == df.iloc[i]["Parch"]) & (df['Pclass'] == df.iloc[i]["Pclass"]))].median()
    if not np.isnan(age_pred) :
        df['Age'].iloc[i] = age_pred
    else :
        df['Age'].iloc[i] = age_med

# %% [markdown]
# ###  Encoding Categorical Features

# %%
# Using Label encoder for transforming Categorical data
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in Categorical_features:
    df[i] = le.fit_transform(df[i])
df.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked  Initial
# 0         0       3    1  22.0      1      0   7.2500         2        2
# 1         1       1    0  38.0      1      0  71.2833         0        3
# 2         1       3    0  26.0      0      0   7.9250         2        1
# 3         1       1    0  35.0      1      0  53.1000         2        3
# 4         0       3    1  35.0      0      0   8.0500         2        2

# %% [markdown]
# ### Standard Scaler

# %%
# Splitting data in target and dependent feature
X = df.drop(['Survived'], axis =1)
Y = df['Survived']

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
X_scale = scaler.fit_transform(X)

# %% [markdown]
# # **Machine Learning Model Building**

# %%
#Importing Machine learning Model library
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.svm import SVC
from sklearn.ensemble import AdaBoostRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import  Ridge
from sklearn.linear_model import  Lasso
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state=67, test_size=.25)
print('Training feature matrix size:',X_train.shape)
print('Training target vector size:',Y_train.shape)
print('Test feature matrix size:',X_test.shape)
print('Test target vector size:',Y_test.shape)
# Out:
# Training feature matrix size: (657, 8)
# Training target vector size: (657,)
# Test feature matrix size: (219, 8)
# Test target vector size: (219,)

# %%
lnr=LinearRegression()
lr=LogisticRegression()
rf = RandomForestRegressor()
dtc = DecisionTreeRegressor()
adb=AdaBoostRegressor()
knn=KNeighborsClassifier(n_neighbors = 18)

model = [lnr,lr,rf,knn,dtc,adb]

for m in model:
    m.fit(X_train,Y_train)
    m.score(X_train,Y_train)
    y_pred = m.predict(X_test)
    print('\n')                                        
    print('Error of ', m, ':')
    print('Mean absolute error :', mean_absolute_error(Y_test,y_pred))
    print('Mean squared error :', mean_squared_error(Y_test,y_pred))
    print('Root Mean Squared Error:', np.sqrt(mean_squared_error(Y_test,y_pred)))
    print('\n')

    print('R2 Score :')
    print(r2_score(Y_test,y_pred)) 
    print('='*50)
# Out:
# Error of  LinearRegression() :
# Mean absolute error : 0.2759631789423892
# Mean squared error : 0.12596183709214193
# Root Mean Squared Error: 0.35491102700837845
#
#
# R2 Score :
# 0.4441244323908522
# ==================================================
#
#
# Error of  LogisticRegression() :
# Mean absolute error : 0.2054794520547945
# Mean squared error : 0.2054794520547945
# Root Mean Squared Error: 0.45329841391162456
#
#
# R2 Score :
# 0.09320942215679073
# ==================================================
#
#
# Error of  RandomForestRegressor() :
# Mean absolute error : 0.21988457973369335
# Mean squared error : 0.12867151815542224
# Root Mean Squared Error: 0.35870812390496853
#
#
# R2 Score :
# 0.4321664812060907
# ==================================================
#
#
# Error of  KNeighborsClassifier(n_neighbors=18) :
# Mean absolute error : 0.2602739726027397
# Mean squared error : 0.2602739726027397
# Root Mean Squared Error: 0.5101705328640019
#
#
# R2 Score :
# -0.14860139860139854
# ==================================================
#
#
# Error of  DecisionTreeRegressor() :
# Mean absolute error : 0.22516489091831557
# Mean squared error : 0.21829884803574737
# Root Mean Squared Error: 0.46722462267708814
#
#
# R2 Score :
# 0.03663681904283422
# ==================================================
#
#
# Error of  AdaBoostRegressor() :
# Mean absolute error : 0.3477643144037568
# Mean squared error : 0.14735962300611413
# Root Mean Squared Error: 0.38387448861068396
#
#
# R2 Score :
# 0.3496949872105043
# ==================================================

# %% [markdown]
# ## **Hyper Parameter Tuning : GridSearchCV**

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameter = [{'fit_intercept': [True, False], #default: True
            'penalty': ['l1','l2'],
            'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'], #default: lbfgs
            'random_state': [69]
             }]

# %%
GCV = GridSearchCV(LogisticRegression(),parameter,verbose=5)
GCV.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV 1/5] END fit_intercept=True, penalty=l1, random_state=69, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/5] END fit_intercept=True, penalty=l1, random_state=69, solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/5] END fit_intercept=True, penalty=l1, random_state=69, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/5] END fit_intercept=True, penalty=l1, random_state=69, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/5] END fit_intercept=True, penalty=l1, random_state=69, solver=newton-cg;, score=nan total time=   0.0s
# [CV 1/5] END fit_intercept=True, penalty=l1, random_state=69, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END fit_intercept=True, penalty=l1, random_state=69, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END fit_intercept=True, penalty=l1, random_state=69, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END fit_intercept=True, penalty=l1, random_state=69, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END fit_intercept=True, penalty=l1, random_state=69, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END fit_intercept=True, penalty=l1, random_state=69, solver=liblinear;, score=0.727 total time=   0.0s
# [CV 2/5] END fit_intercept=True, penalty=l1, random_state=69, solver=liblinear;, score=0.818 total time=   0.0s
# [CV 3/5] END fit_intercept=True, penalty=l1, random_state=69, solver=liblinear;, score=0.809 total time=   0.0s
# [CV 4/5] END fit_intercept=True, penalty=l1, random_state=69, solver=liblinear;, score=0.794 total time=   0.0s
# [CV 5/5] END fit_intercept=True, penalty=l1, random_state=69, solver=liblinear;, score=0.794 total time=   0.0s
# [CV 1/5] END fit_intercept=True, penalty=l1, random_state=69, solver=sag;, score=nan total time=   0.0s
# [CV 2/5] END fit_intercept=True, penalty=l1, random_state=69, solver=sag;, score=nan total time=   0.0s
# [CV 3/5] END fit_intercept=True, penalty=l1, random_state=69, solver=sag;, score=nan total time=   0.0s
# [CV 4/5] END fit_intercept=True, penalty=l1, random_state=69, solver=sag;, score=nan total time=   0.0s
# [CV 5/5] END fit_intercept=True, penalty=l1, random_state=69, solver=sag;, score=nan total time=   0.0s
# [CV 1/5] END fit_intercept=True, penalty=l1, random_state=69, solver=saga;, score=0.682 total time=   0.0s
# [CV 2/5] END fit_intercept=True, penalty=l1, random_state=69, solver=saga;, score=0.682 total time=   0.0s
# [CV 3/5] END fit_intercept=True, penalty=l1, random_state=69, solver=saga;, score=0.641 total time=   0.0s
# [CV 4/5] END fit_intercept=True, penalty=l1, random_state=69, solver=saga;, score=0.664 total time=   0.0s
# [CV 5/5] END fit_intercept=True, penalty=l1, random_state=69, solver=saga;, score=0.603 total time=   0.0s
# [CV 1/5] END fit_intercept=True, penalty=l2, random_state=69, solver=newton-cg;, score=0.727 total time=   0.0s
# [CV 2/5] END fit_intercept=True, penalty=l2, random_state=69, solver=newton-cg;, score=0.818 total time=   0.0s
# [CV 3/5] END fit_intercept=True, penalty=l2, random_state=69, solver=newton-cg;, score=0.802 total time=   0.0s
# [CV 4/5] END fit_intercept=True, penalty=l2, random_state=69, solver=newton-cg;, score=0.809 total time=   0.0s
# [CV 5/5] END fit_intercept=True, penalty=l2, random_state=69, solver=newton-cg;, score=0.832 total time=   0.0s
# [CV 1/5] END fit_intercept=True, penalty=l2, random_state=69, solver=lbfgs;, score=0.727 total time=   0.0s
# [CV 2/5] END fit_intercept=True, penalty=l2, random_state=69, solver=lbfgs;, score=0.818 total time=   0.0s
# [CV 3/5] END fit_intercept=True, penalty=l2, random_state=69, solver=lbfgs;, score=0.794 total time=   0.0s
# [CV 4/5] END fit_intercept=True, penalty=l2, random_state=69, solver=lbfgs;, score=0.809 total time=   0.0s
# [CV 5/5] END fit_intercept=True, penalty=l2, random_state=69, solver=lbfgs;, score=0.832 total time=   0.0s
# [CV 1/5] END fit_intercept=True, penalty=l2, random_state=69, solver=liblinear;, score=0.727 total time=   0.0s
# [CV 2/5] END fit_intercept=True, penalty=l2, random_state=69, solver=liblinear;, score=0.818 total time=   0.0s
# [CV 3/5] END fit_intercept=True, penalty=l2, random_state=69, solver=liblinear;, score=0.817 total time=   0.0s
# [CV 4/5] END fit_intercept=True, penalty=l2, random_state=69, solver=liblinear;, score=0.794 total time=   0.0s
# [CV 5/5] END fit_intercept=True, penalty=l2, random_state=69, solver=liblinear;, score=0.786 total time=   0.0s
# [CV 1/5] END fit_intercept=True, penalty=l2, random_state=69, solver=sag;, score=0.712 total time=   0.0s
# [CV 2/5] END fit_intercept=True, penalty=l2, random_state=69, solver=sag;, score=0.667 total time=   0.0s
# [CV 3/5] END fit_intercept=True, penalty=l2, random_state=69, solver=sag;, score=0.664 total time=   0.0s
# [CV 4/5] END fit_intercept=True, penalty=l2, random_state=69, solver=sag;, score=0.695 total time=   0.0s
# [CV 5/5] END fit_intercept=True, penalty=l2, random_state=69, solver=sag;, score=0.626 total time=   0.0s
# [CV 1/5] END fit_intercept=True, penalty=l2, random_state=69, solver=saga;, score=0.682 total time=   0.0s
# [CV 2/5] END fit_intercept=True, penalty=l2, random_state=69, solver=saga;, score=0.682 total time=   0.0s
# [CV 3/5] END fit_intercept=True, penalty=l2, random_state=69, solver=saga;, score=0.641 total time=   0.0s
# [CV 4/5] END fit_intercept=True, penalty=l2, random_state=69, solver=saga;, score=0.664 total time=   0.0s
# [CV 5/5] END fit_intercept=True, penalty=l2, random_state=69, solver=saga;, score=0.603 total time=   0.0s
# [CV 1/5] END fit_intercept=False, penalty=l1, random_state=69, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/5] END fit_intercept=False, penalty=l1, random_state=69, solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/5] END fit_intercept=False, penalty=l1, random_state=69, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/5] END fit_intercept=False, penalty=l1, random_state=69, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/5] END fit_intercept=False, penalty=l1, random_state=69, solver=newton-cg;, score=nan total time=   0.0s
# [CV 1/5] END fit_intercept=False, penalty=l1, random_state=69, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END fit_intercept=False, penalty=l1, random_state=69, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END fit_intercept=False, penalty=l1, random_state=69, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END fit_intercept=False, penalty=l1, random_state=69, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END fit_intercept=False, penalty=l1, random_state=69, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END fit_intercept=False, penalty=l1, random_state=69, solver=liblinear;, score=0.712 total time=   0.0s
# [CV 2/5] END fit_intercept=False, penalty=l1, random_state=69, solver=liblinear;, score=0.848 total time=   0.0s
# [CV 3/5] END fit_intercept=False, penalty=l1, random_state=69, solver=liblinear;, score=0.794 total time=   0.0s
# [CV 4/5] END fit_intercept=False, penalty=l1, random_state=69, solver=liblinear;, score=0.779 total time=   0.0s
# [CV 5/5] END fit_intercept=False, penalty=l1, random_state=69, solver=liblinear;, score=0.794 total time=   0.0s
# [CV 1/5] END fit_intercept=False, penalty=l1, random_state=69, solver=sag;, score=nan total time=   0.0s
# [CV 2/5] END fit_intercept=False, penalty=l1, random_state=69, solver=sag;, score=nan total time=   0.0s
# [CV 3/5] END fit_intercept=False, penalty=l1, random_state=69, solver=sag;, score=nan total time=   0.0s
# [CV 4/5] END fit_intercept=False, penalty=l1, random_state=69, solver=sag;, score=nan total time=   0.0s
# [CV 5/5] END fit_intercept=False, penalty=l1, random_state=69, solver=sag;, score=nan total time=   0.0s
# [CV 1/5] END fit_intercept=False, penalty=l1, random_state=69, solver=saga;, score=0.682 total time=   0.0s
# [CV 2/5] END fit_intercept=False, penalty=l1, random_state=69, solver=saga;, score=0.682 total time=   0.0s
# [CV 3/5] END fit_intercept=False, penalty=l1, random_state=69, solver=saga;, score=0.641 total time=   0.0s
# [CV 4/5] END fit_intercept=False, penalty=l1, random_state=69, solver=saga;, score=0.664 total time=   0.0s
# [CV 5/5] END fit_intercept=False, penalty=l1, random_state=69, solver=saga;, score=0.603 total time=   0.0s
# [CV 1/5] END fit_intercept=False, penalty=l2, random_state=69, solver=newton-cg;, score=0.705 total time=   0.0s
# [CV 2/5] END fit_intercept=False, penalty=l2, random_state=69, solver=newton-cg;, score=0.841 total time=   0.0s
# [CV 3/5] END fit_intercept=False, penalty=l2, random_state=69, solver=newton-cg;, score=0.794 total time=   0.0s
# [CV 4/5] END fit_intercept=False, penalty=l2, random_state=69, solver=newton-cg;, score=0.771 total time=   0.0s
# [CV 5/5] END fit_intercept=False, penalty=l2, random_state=69, solver=newton-cg;, score=0.794 total time=   0.0s
# [CV 1/5] END fit_intercept=False, penalty=l2, random_state=69, solver=lbfgs;, score=0.705 total time=   0.0s
# [CV 2/5] END fit_intercept=False, penalty=l2, random_state=69, solver=lbfgs;, score=0.841 total time=   0.0s
# [CV 3/5] END fit_intercept=False, penalty=l2, random_state=69, solver=lbfgs;, score=0.794 total time=   0.0s
# [CV 4/5] END fit_intercept=False, penalty=l2, random_state=69, solver=lbfgs;, score=0.771 total time=   0.0s
# [CV 5/5] END fit_intercept=False, penalty=l2, random_state=69, solver=lbfgs;, score=0.794 total time=   0.0s
# [CV 1/5] END fit_intercept=False, penalty=l2, random_state=69, solver=liblinear;, score=0.705 total time=   0.0s
# [CV 2/5] END fit_intercept=False, penalty=l2, random_state=69, solver=liblinear;, score=0.841 total time=   0.0s
# [CV 3/5] END fit_intercept=False, penalty=l2, random_state=69, solver=liblinear;, score=0.794 total time=   0.0s
# [CV 4/5] END fit_intercept=False, penalty=l2, random_state=69, solver=liblinear;, score=0.771 total time=   0.0s
# [CV 5/5] END fit_intercept=False, penalty=l2, random_state=69, solver=liblinear;, score=0.794 total time=   0.0s
# [CV 1/5] END fit_intercept=False, penalty=l2, random_state=69, solver=sag;, score=0.712 total time=   0.0s
# [CV 2/5] END fit_intercept=False, penalty=l2, random_state=69, solver=sag;, score=0.674 total time=   0.0s
# [CV 3/5] END fit_intercept=False, penalty=l2, random_state=69, solver=sag;, score=0.664 total time=   0.0s
# [CV 4/5] END fit_intercept=False, penalty=l2, random_state=69, solver=sag;, score=0.695 total time=   0.0s
# [CV 5/5] END fit_intercept=False, penalty=l2, random_state=69, solver=sag;, score=0.626 total time=   0.0s
# [CV 1/5] END fit_intercept=False, penalty=l2, random_state=69, solver=saga;, score=0.682 total time=   0.0s
# [CV 2/5] END fit_intercept=False, penalty=l2, random_state=69, solver=saga;, score=0.682 total time=   0.0s
# [CV 3/5] END fit_intercept=False, penalty=l2, random_state=69, solver=saga;, score=0.641 total time=   0.0s
# [CV 4/5] END fit_intercept=False, penalty=l2, random_state=69, solver=saga;, score=0.664 total time=   0.0s
# [CV 5/5] END fit_intercept=False, penalty=l2, random_state=69, solver=saga;, score=0.603 total time=   0.0s
# GridSearchCV(estimator=LogisticRegression(),
#              param_grid=[{'fit_intercept': [True, False],
#                           'penalty': ['l1', 'l2'], 'random_state': [69],
#                           'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag',
#                                      'saga']}],
#              verbose=5)
# GridSearchCV(estimator=LogisticRegression(),
#              param_grid=[{'fit_intercept': [True, False],
#                           'penalty': ['l1', 'l2'], 'random_state': [69],
#                           'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag',
#                                      'saga']}],
#              verbose=5)

# %%
GCV.best_params_
# Out:
# {'fit_intercept': True,
#  'penalty': 'l2',
#  'random_state': 69,
#  'solver': 'newton-cg'}

# %% [markdown]
# #### Final Model

# %%
Final_mod = LogisticRegression(fit_intercept =True,penalty= "l2",solver='newton-cg',random_state= 69)
Final_mod.fit(X_train,Y_train)
y_pred=Final_mod.predict(X_test)
print('Final Random Forest Classifier Model')
print('Accuracy Score :\n', accuracy_score(Y_test, y_pred))
print('\n')
print('Confusion matrix of Random Forest Classifier :\n',confusion_matrix(Y_test, y_pred))
print('\n')
print('Classification Report of Random Forest Classifier\n',classification_report(Y_test, y_pred))
# Out:
# Final Random Forest Classifier Model
# Accuracy Score :
#  0.7945205479452054
#
#
# Confusion matrix of Random Forest Classifier :
#  [[122  21]
#  [ 24  52]]
#
#
# Classification Report of Random Forest Classifier
#                precision    recall  f1-score   support
#
#            0       0.84      0.85      0.84       143
#            1       0.71      0.68      0.70        76
#
#     accuracy                           0.79       219
#    macro avg       0.77      0.77      0.77       219
# weighted avg       0.79      0.79      0.79       219

# %%
# Lets plot confusion matrix for  FinalModel
Matrix = confusion_matrix(Y_test, y_pred)

x_labels = ["NO","YES"]
y_labels = ["NO","YES"]

fig , ax = plt.subplots(figsize=(5,5))
sns.heatmap(Matrix, annot = True,linewidths=.2, linecolor="black", fmt = ".0f", ax=ax, 
            cmap="plasma", xticklabels = x_labels, yticklabels = y_labels)

plt.xlabel("Predicted Label",fontsize=14,fontweight='bold')
plt.ylabel("True Label",fontsize=14,fontweight='bold')
plt.title('Confusion Matrix for Final Model',fontsize=20,fontweight='bold')
plt.show()

# %% [markdown]
# ## Saving model

# %%
import joblib
joblib.dump(Final_mod,'Titanic_Survival_Project.pkl')
# Out:
# ['Titanic_Survival_Project.pkl']

# %% [markdown]
# ## Predicting the Final Model

# %%
# Prediction
prediction = Final_mod.predict(X_test)

# %%
Actual = np.array(Y_test)
df_Pred = pd.DataFrame()
df_Pred["Predicted Values"] = prediction
df_Pred["Actual Values"] = Actual
df_Pred.head()
# Out:
#    Predicted Values  Actual Values
# 0                 0              1
# 1                 1              1
# 2                 0              0
# 3                 1              1
# 4                 0              0
